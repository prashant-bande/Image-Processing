# %%
from skimage import color, io
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
def show_image(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
img = io.imread('dog.jpg')
grayscale = color.rgb2gray(img)

show_image(grayscale, 'grayscale')

# %%
# Import the modules from skimage
from skimage import color, data

# Load the rocket image
rocket = data.load('rocket.jpg')

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket)

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

# %% [markdown]
# ### Images as ndarray

# %%
dog = plt.imread('dog.jpg')
type(dog)
# Out:
# numpy.ndarray

# %%
dog.shape
# Out:
# (720, 1280, 3)

# %%
dog.size
# Out:
# 2764800

# %% [markdown]
# ### Color with Numpy

# %%
# Obtaining red values of the images
red = dog[:, :, 0]
# Obtaining green values of the images
green = dog[:, :, 1]
# Obtaining blue values of the images
blue = dog[:, :, 2]

# %%
plt.imshow(green)
plt.title('Green')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Flipping image

# %%
# Vertically

vertFlipped = np.flipud(dog)
show_image(vertFlipped, "Vertically Flipped Image")

# %%
# Horizontally
horiFlipped = np.fliplr(dog)
show_image(horiFlipped, "Horizontally Flipped Image")

# %% [markdown]
# ### Histogram

# %%
red = dog[:, :, 0]
plt.hist(red.ravel(), bins=256, color='r')
plt.title("Red Histogram")
plt.show()

# %%
blue = dog[:, :, 2]
plt.hist(blue.ravel(), bins=256)
plt.title("Red Histogram")
plt.show()

# %% [markdown]
# ### Thresholding
#
# Thresholding is the simplest method for Image segmentation. It isolates the elements and helpful in object detection, face recognition, etc.

# %%
from skimage.data import camera
image = camera()
thresh = 127
binary = image >= thresh
show_image(binary, 'Thresholded Image')
show_image(image, 'Original Image')

# %% [markdown]
# #### Category:
#
#     * Global or Histogram based - good for uniform background
#     * Local or Adaptive - for uneven background illumination

# %%
# Import the otsu threshold function
from skimage.filters import threshold_otsu

# Load image
chess_pieces_image = io.imread('bw.jpg')

# Make the image grayscale using rgb2gray
chess_pieces_image_gray = color.rgb2gray(chess_pieces_image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(chess_pieces_image_gray)

# Apply thresholding to the image
binary = chess_pieces_image_gray > thresh

# Show the image
show_image(binary, 'Binary image')

# %%
from skimage.filters import threshold_local
from skimage.data import camera
image = camera()
block_size = 35
local_thresh = threshold_local(image, block_size, offset=10)

binary = image >= local_thresh
show_image(binary, 'Thresholded Image')
show_image(image, 'Original Image')

# %%
# Import the try all function
from skimage.filters import try_all_threshold

# Import the rgb to gray convertor function 
from skimage.color import rgb2gray

# Turn the fruits image to grayscale
grayscale = rgb2gray(image)

# Use the try all method on the grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False)

# Show the resulting plots
plt.show()

# %%
# Import threshold and gray convertor functions
from skimage.filters import threshold_otsu
from skimage.color import rgb2gray

# Load image
tools_image = io.imread('shapes52.jpg')

# Turn the image grayscale
tools_image = rgb2gray(tools_image)

# Obtain the optimal thresh
thresh = threshold_otsu(tools_image)

# Obtain the binary image by applying thresholding
binary_image = tools_image > thresh

# Show the resulting binary image
show_image(binary_image, 'Binarized image')
